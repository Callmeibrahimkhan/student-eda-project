# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("students.csv")
df
# Out:
#    Student_ID    Name  Age  Gender              Department       City  CGPA  \
# 0         101     Ali   20    Male        Computer Science   Peshawar  3.45
# 1         102    Sara   21  Female    Software Engineering  Islamabad  3.80
# 2         103   Ahmed   22    Male        Computer Science     Lahore  3.10
# 3         104  Ayesha   20  Female            Data Science    Karachi  3.92
# 4         105   Hamza   23    Male  Information Technology   Peshawar  2.95
# 5         106  Zainab   21  Female        Computer Science     Quetta  3.55
# 6         107   Bilal   22    Male            Data Science     Lahore  3.70
# 7         108   Maria   20  Female    Software Engineering    Karachi  3.65
# 8         109   Usman   23    Male  Information Technology  Islamabad  3.20
# 9         110    Hina   21  Female        Computer Science   Peshawar  3.85
#
#    Attendance
# 0          90
# 1          95
# 2          88
# 3          97
# 4          80
# 5          92
# 6          89
# 7          94
# 8          85
# 9          98

# %%
df.head()
# Out:
#    Student_ID    Name  Age  Gender              Department       City  CGPA  \
# 0         101     Ali   20    Male        Computer Science   Peshawar  3.45
# 1         102    Sara   21  Female    Software Engineering  Islamabad  3.80
# 2         103   Ahmed   22    Male        Computer Science     Lahore  3.10
# 3         104  Ayesha   20  Female            Data Science    Karachi  3.92
# 4         105   Hamza   23    Male  Information Technology   Peshawar  2.95
#
#    Attendance
# 0          90
# 1          95
# 2          88
# 3          97
# 4          80

# %%
df.tail()
# Out:
#    Student_ID    Name  Age  Gender              Department       City  CGPA  \
# 5         106  Zainab   21  Female        Computer Science     Quetta  3.55
# 6         107   Bilal   22    Male            Data Science     Lahore  3.70
# 7         108   Maria   20  Female    Software Engineering    Karachi  3.65
# 8         109   Usman   23    Male  Information Technology  Islamabad  3.20
# 9         110    Hina   21  Female        Computer Science   Peshawar  3.85
#
#    Attendance
# 5          92
# 6          89
# 7          94
# 8          85
# 9          98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         10 non-null     int64
#  3   Gender      10 non-null     object
#  4   Department  10 non-null     object
#  5   City        10 non-null     object
#  6   CGPA        10 non-null     float64
#  7   Attendance  10 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 772.0+ bytes

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Student_ID    Name  Age  Gender              Department       City  CGPA  \
# 0         101     Ali   20    Male        Computer Science   Peshawar  3.45
# 1         102    Sara   21  Female    Software Engineering  Islamabad  3.80
# 2         103   Ahmed   22    Male        Computer Science     Lahore  3.10
# 3         104  Ayesha   20  Female            Data Science    Karachi  3.92
# 4         105   Hamza   23    Male  Information Technology   Peshawar  2.95
# 5         106  Zainab   21  Female        Computer Science     Quetta  3.55
# 6         107   Bilal   22    Male            Data Science     Lahore  3.70
# 7         108   Maria   20  Female    Software Engineering    Karachi  3.65
# 8         109   Usman   23    Male  Information Technology  Islamabad  3.20
# 9         110    Hina   21  Female        Computer Science   Peshawar  3.85
#
#    Attendance
# 0          90
# 1          95
# 2          88
# 3          97
# 4          80
# 5          92
# 6          89
# 7          94
# 8          85
# 9          98  >

# %%
df.shape
# Out:
# (10, 8)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'City', 'CGPA',
#        'Attendance'],
#       dtype='object')

# %%
df.isnull()
# Out:
#    Student_ID   Name    Age  Gender  Department   City   CGPA  Attendance
# 0       False  False  False   False       False  False  False       False
# 1       False  False  False   False       False  False  False       False
# 2       False  False  False   False       False  False  False       False
# 3       False  False  False   False       False  False  False       False
# 4       False  False  False   False       False  False  False       False
# 5       False  False  False   False       False  False  False       False
# 6       False  False  False   False       False  False  False       False
# 7       False  False  False   False       False  False  False       False
# 8       False  False  False   False       False  False  False       False
# 9       False  False  False   False       False  False  False       False

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           0
# Gender        0
# Department    0
# City          0
# CGPA          0
# Attendance    0
# dtype: int64

# %%
df["Department"].unique()
# Out:
# array(['Computer Science', 'Software Engineering', 'Data Science',
#        'Information Technology'], dtype=object)

# %%
df["City"].unique()
# Out:
# array(['Peshawar', 'Islamabad', 'Lahore', 'Karachi', 'Quetta'],
#       dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Department"].value_counts()
# Out:
# Department
# Computer Science          4
# Software Engineering      2
# Data Science              2
# Information Technology    2
# Name: count, dtype: int64

# %%
df["CGPA"].mean()
# Out:
# 3.5169999999999995

# %%
df['CGPA'].max()
# Out:
# 3.92

# %%
df["CGPA"].min()
# Out:
# 2.95

# %%
df[df["CGPA"]>3.5]
# Out:
#    Student_ID    Name  Age  Gender            Department       City  CGPA  \
# 1         102    Sara   21  Female  Software Engineering  Islamabad  3.80
# 3         104  Ayesha   20  Female          Data Science    Karachi  3.92
# 5         106  Zainab   21  Female      Computer Science     Quetta  3.55
# 6         107   Bilal   22    Male          Data Science     Lahore  3.70
# 7         108   Maria   20  Female  Software Engineering    Karachi  3.65
# 9         110    Hina   21  Female      Computer Science   Peshawar  3.85
#
#    Attendance
# 1          95
# 3          97
# 5          92
# 6          89
# 7          94
# 9          98

# %%
df[df["City"]=="Peshawar"]
# Out:
#    Student_ID   Name  Age  Gender              Department      City  CGPA  \
# 0         101    Ali   20    Male        Computer Science  Peshawar  3.45
# 4         105  Hamza   23    Male  Information Technology  Peshawar  2.95
# 9         110   Hina   21  Female        Computer Science  Peshawar  3.85
#
#    Attendance
# 0          90
# 4          80
# 9          98

# %%
df[df["Department"]=="Computer Science"]
# Out:
#    Student_ID    Name  Age  Gender        Department      City  CGPA  \
# 0         101     Ali   20    Male  Computer Science  Peshawar  3.45
# 2         103   Ahmed   22    Male  Computer Science    Lahore  3.10
# 5         106  Zainab   21  Female  Computer Science    Quetta  3.55
# 9         110    Hina   21  Female  Computer Science  Peshawar  3.85
#
#    Attendance
# 0          90
# 2          88
# 5          92
# 9          98

# %%
df.sort_values("CGPA")
# Out:
#    Student_ID    Name  Age  Gender              Department       City  CGPA  \
# 4         105   Hamza   23    Male  Information Technology   Peshawar  2.95
# 2         103   Ahmed   22    Male        Computer Science     Lahore  3.10
# 8         109   Usman   23    Male  Information Technology  Islamabad  3.20
# 0         101     Ali   20    Male        Computer Science   Peshawar  3.45
# 5         106  Zainab   21  Female        Computer Science     Quetta  3.55
# 7         108   Maria   20  Female    Software Engineering    Karachi  3.65
# 6         107   Bilal   22    Male            Data Science     Lahore  3.70
# 1         102    Sara   21  Female    Software Engineering  Islamabad  3.80
# 9         110    Hina   21  Female        Computer Science   Peshawar  3.85
# 3         104  Ayesha   20  Female            Data Science    Karachi  3.92
#
#    Attendance
# 4          80
# 2          88
# 8          85
# 0          90
# 5          92
# 7          94
# 6          89
# 1          95
# 9          98
# 3          97
